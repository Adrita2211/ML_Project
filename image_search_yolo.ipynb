# %% [markdown]
# <a href="https://colab.research.google.com/github/Adrita2211/ML_Project/blob/object_detection/image_search_yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Core libraries
# !pip install torch torchvision torchaudio  # PyTorch with CUDA support (if available)
# !pip install opencv-python  # OpenCV for image processing (cv2)
# !pip install numpy  # NumPy for numerical operations

# Additional dependencies (if needed)
# !pip install ultralytics  # For YOLOv8 (if you're using it)
# !pip install faiss-cpu  # For FAISS (CPU version, for vector search)
# OR (if you have CUDA)
# !pip install faiss-gpu  # GPU-accelerated FAISS

# For image preprocessing (if using torchvision transforms)
# !pip install pillow  # Required for some torchvision transforms
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 90.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 67.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 54.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
import cv2
import numpy as np
import torch
from ultralytics import YOLO

# Load YOLOv8 model
model = YOLO("yolov8n.pt")  # or yolov8s, yolov8m, etc.

def extract_embeddings(image_path, model):
    """
    Extract embeddings from YOLOv8's backbone (feature extractor).
    Returns a flattened embedding vector.
    """
    # 1. Read and preprocess the image
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert to RGB
    img = cv2.resize(img, (640, 640))  # YOLOv8 default input size
    img = img.transpose(2, 0, 1)  # HWC to CHW
    img = np.ascontiguousarray(img)  # Ensure memory contiguity
    img = torch.from_numpy(img).float().unsqueeze(0) / 255.0 # to torch tensor, add batch dim, normalize

    # 2. Pass the image through the model's backbone
    with torch.no_grad():
        features = model.model.backbone(img)  # Returns a dictionary of feature maps

    # 3. Extract the last feature map (highest-level features)
    embedding = features[model.model.backbone.stride[-1]]  # or model.model.get_embedding()

    # 4. Global average pooling to get a 1D embedding vector
    embedding = torch.mean(embedding, dim=[2, 3]).squeeze() # spatial dimensions [2,3]

    # 5. Convert to NumPy array and flatten
    embedding = embedding.cpu().numpy().flatten()

    return embedding

# Example usage
image_paths = ["/content/sample_data/img_1.png", "/content/sample_data/img_2.png", "/content/sample_data/img_3.png","/content/sample_data/img_4.png","/content/sample_data/img_5.png"]
embeddings_list = [extract_embeddings(img_path, model) for img_path in image_paths]
print("Embeddings shape:", np.array(embeddings_list).shape)


# Example usage
image_paths = ["/content/sample_data/img_1.png", "/content/sample_data/img_2.png", "/content/sample_data/img_3.png","/content/sample_data/img_4.png","/content/sample_data/img_5.png"]
embeddings_list = [extract_embeddings(img_path, model) for img_path in image_paths]
print("Embeddings shape:", np.array(embeddings_list).shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-018c9158e4ae> in <cell line: 0>()
#      37 # Example usage
#      38 image_paths = ["/content/sample_data/img_1.png", "/content/sample_data/img_2.png", "/content/sample_data/img_3.png","/content/sample_data/img_4.png","/content/sample_data/img_5.png"]
# ---> 39 embeddings_list = [extract_embeddings(img_path, model) for img_path in image_paths]
#      40 print("Embeddings shape:", np.array(embeddings_list).shape)
#      41
#
# <ipython-input-20-018c9158e4ae> in <listcomp>(.0)
#      37 # Example usage
#      38 image_paths = ["/content/sample_data/img_1.png", "/content/sample_data/img_2.png", "/content/sample_data/img_3.png","/content/sample_data/img_4.png","/content/sample_data/img_5.png"]
# ---> 39 embeddings_list = [extract_embeddings(img_path, model) for img_path in image_paths]
# ...

# %%
image_paths = ["/content/sample_data/img_1.png", "/content/sample_data/img_2.png", "/content/sample_data/img_3.png","/content/sample_data/img_4.png","/content/sample_data/img_5.png"]
embeddings_list = [extract_embeddings(img_path, model) for img_path in image_paths]
print("Embeddings shape:", np.array(embeddings_list).shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-82339abb2961> in <cell line: 0>()
#       1 image_paths = ["/content/sample_data/img_1.png", "/content/sample_data/img_2.png", "/content/sample_data/img_3.png","/content/sample_data/img_4.png","/content/sample_data/img_5.png"]
# ----> 2 embeddings_list = [extract_embeddings(img_path, model) for img_path in image_paths]
#       3 print("Embeddings shape:", np.array(embeddings_list).shape)
#
# <ipython-input-16-82339abb2961> in <listcomp>(.0)
#       1 image_paths = ["/content/sample_data/img_1.png", "/content/sample_data/img_2.png", "/content/sample_data/img_3.png","/content/sample_data/img_4.png","/content/sample_data/img_5.png"]
# ----> 2 embeddings_list = [extract_embeddings(img_path, model) for img_path in image_paths]
#       3 print("Embeddings shape:", np.array(embeddings_list).shape)
#
# ...
